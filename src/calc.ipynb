# %%
def calc(x):
    return  97.34482 + (10.20562 - 97.34482)/(1 + pow(pow((x/3.590438),42.12697),0.8958739))

# %%
def calc(x):
    return (951702.7 - 1244424*x + 648360.4*pow(x,2) - 168299.4*pow(x,3) + 21772.27*pow(x,4) - 1123.258*pow(x,5))

# %%
import numpy as np
import matplotlib.pyplot as plt



x = np.array([4.3,4.2,4.1,4,3.95,3.9,3.8,3.7,3.68,3.66,3.64,3.62,3.6,3.55,3.5,3.4,3.3,3.2,3.1,3,2.9,2.8,2.7,2.6,2.5])
y = np.array([100,99,97,95,93,90,85,80,75,70,60,55,50,40,30,20,15,13,10,5,1,0,0,0,0])
p = np.poly1d(np.polyfit(x, y,6))
print(p)
t = np.linspace(2.5, 4.3, 100)
plt.plot(x, y, 'o', t, p(t), '-')
plt.show()
# Out:
#        6        5             4             3             2
# 309.1 x - 6231 x + 5.188e+04 x - 2.284e+05 x + 5.608e+05 x - 7.284e+05 x + 3.911e+05

# %%
import numpy as np
import matplotlib.pyplot as plt



x = np.linspace(4.3,2.5, 100)
y = calc(x)

plt.plot(x, y, 'o')
plt.show()
